# %%
import pandas as pd

dataset = pd.read_csv("data.csv")

print(dataset.head())
# Out:
#         id                                    resume_text_256  \
# 0  RS00000  8+ years experience; key skills: linux, contai...
# 1  RS00001  0+ years experience; key skills: kafka, ci/cd,...
# 2  RS00002  0+ years experience; key skills: bug-tracking,...
# 3  RS00003  2+ years experience; key skills: test-cases, b...
# 4  RS00004  9+ years experience; key skills: testing, bug-...
#
#                                          jd_text_128 job_family seniority  \
# 0  We are hiring a Senior DevOps professional. Mu...     DevOps    Senior
# 1  We are hiring a Junior PM professional. Must h...         PM    Junior
# 2  We are hiring a Junior QA professional. Must h...         QA    Junior
# 3  We are hiring a Mid QA professional. Must have...         QA       Mid
# 4  We are hiring a Senior QA professional. Must h...         QA    Senior
#
#    advance
# 0        1
# 1        0
# 2        1
# 3        1
# 4        1

# %%
dataset.shape
# Out:
# (2000, 6)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               2000 non-null   object
#  1   resume_text_256  2000 non-null   object
#  2   jd_text_128      2000 non-null   object
#  3   job_family       2000 non-null   object
#  4   seniority        2000 non-null   object
#  5   advance          2000 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 93.9+ KB

# %%
print(dataset.duplicated())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Length: 2000, dtype: bool

# %%
print(dataset.isnull().sum())
# Out:
# id                 0
# resume_text_256    0
# jd_text_128        0
# job_family         0
# seniority          0
# advance            0
# dtype: int64

# %%
dataset = dataset.drop('id', errors='ignore')
dataset.columns
# Out:
# Index(['id', 'resume_text_256', 'jd_text_128', 'job_family', 'seniority',
#        'advance'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

job_encoder = LabelEncoder()
seniority_encoder = LabelEncoder()
dataset['job_family2'] = dataset['job_family']
dataset['job_family'] = job_encoder.fit_transform(dataset['job_family'])
dataset['seniority'] = seniority_encoder.fit_transform(dataset['seniority'])
print(dataset.head())
# Out:
#         id                                    resume_text_256  \
# 0  RS00000  8+ years experience; key skills: linux, contai...
# 1  RS00001  0+ years experience; key skills: kafka, ci/cd,...
# 2  RS00002  0+ years experience; key skills: bug-tracking,...
# 3  RS00003  2+ years experience; key skills: test-cases, b...
# 4  RS00004  9+ years experience; key skills: testing, bug-...
#
#                                          jd_text_128  job_family  seniority  \
# 0  We are hiring a Senior DevOps professional. Mu...           2          2
# 1  We are hiring a Junior PM professional. Must h...           4          0
# 2  We are hiring a Junior QA professional. Must h...           5          0
# 3  We are hiring a Mid QA professional. Must have...           5          1
# 4  We are hiring a Senior QA professional. Must h...           5          2
#
#    advance job_family2
# 0        1      DevOps
# 1        0          PM
# 2        1          QA
# 3        1          QA
# 4        1          QA

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences


resume_tokenizer = Tokenizer(num_words=5000, oov_token='<OOV>')
resume_tokenizer.fit_on_texts(dataset['resume_text_256'])
resume_sequences = resume_tokenizer.texts_to_sequences(dataset['resume_text_256'])
resume_padded = pad_sequences(resume_sequences)

jd_tokenizer = Tokenizer(num_words=5000, oov_token='<OOV>')
jd_tokenizer.fit_on_texts(dataset['jd_text_128'])
jd_sequences = jd_tokenizer.texts_to_sequences(dataset['jd_text_128'])
jd_padded = pad_sequences(jd_sequences)
print(resume_padded)
# Out:
# [[ 0  0  0 ... 13  2 14]
#  [ 0  0  0 ... 13  2 14]
#  [ 0  0  0 ... 13  2 14]
#  ...
#  [ 0  0  0 ... 13  2 15]
#  [ 0  0  0 ... 13  2 17]
#  [ 0  0  0 ... 13  2 17]]

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

dataset['advance'].value_counts().plot(kind='bar', ax=axes[0], color=['red', 'green'])
axes[0].set_title('Advance vs Reject')
axes[0].set_xticklabels(['Reject', 'Advance'], rotation=0)

dataset['job_family2'].value_counts().plot(kind='bar', ax=axes[1], color='skyblue')
axes[1].set_title('Job Family Distribution')

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, Flatten, Concatenate, Dropout, Input

combined_train = np.concatenate([
    resume_padded_train,
    X_jd_train,
    X_job_family_train,
    X_seniority_train
], axis=1)

combined_test = np.concatenate([
    resume_padded_test,
    X_jd_test,
    X_job_family_test,
    X_seniority_test
], axis=1)

model = Sequential([
    Dense(256, activation='relu', input_shape=(combined_train.shape[1],)),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid')
])

# %%
from tensorflow.keras.optimizers import Adam

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)
history = model.fit(
    combined_train,
    y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=32
)
# Out:
# Epoch 1/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5375 - loss: 1.8153 - val_accuracy: 0.6938 - val_loss: 0.6092
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6187 - loss: 0.8785 - val_accuracy: 0.6906 - val_loss: 0.5947
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6070 - loss: 0.7758 - val_accuracy: 0.6500 - val_loss: 0.5975
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6391 - loss: 0.6964 - val_accuracy: 0.7000 - val_loss: 0.5601
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6664 - loss: 0.6365 - val_accuracy: 0.7250 - val_loss: 0.5374
# Epoch 6/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6844 - loss: 0.5956 - val_accuracy: 0.7156 - val_loss: 0.5238
# Epoch 7/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6992 - loss: 0.5817 - val_accuracy: 0.6844 - val_loss: 0.5361
# Epoch 8/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6883 - loss: 0.5571 - val_accuracy: 0.7375 - val_loss: 0.5144
# Epoch 9/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7289 - loss: 0.5194 - val_accuracy: 0.7250 - val_loss: 0.5132
# Epoch 10/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7336 - loss: 0.5101 - val_accuracy: 0.6625 - val_loss: 0.5346
# Epoch 11/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7352 - loss: 0.5165 - val_accuracy: 0.7250 - val_loss: 0.5172
# Epoch 12/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7305 - loss: 0.4950 - val_accuracy: 0.7375 - val_loss: 0.5171
# Epoch 13/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7383 - loss: 0.4970 - val_accuracy: 0.6844 - val_loss: 0.5171
# Epoch 14/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7469 - loss: 0.4938 - val_accuracy: 0.7500 - val_loss: 0.4872
# Epoch 15/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7570 - loss: 0.4585 - val_accuracy: 0.7469 - val_loss: 0.4782
# Epoch 16/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7648 - loss: 0.4415 - val_accuracy: 0.7625 - val_loss: 0.4788
# Epoch 17/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7906 - loss: 0.4361 - val_accuracy: 0.7500 - val_loss: 0.4620
# Epoch 18/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7844 - loss: 0.4447 - val_accuracy: 0.7594 - val_loss: 0.4659
# Epoch 19/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7906 - loss: 0.4083 - val_accuracy: 0.7719 - val_loss: 0.4611
# Epoch 20/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7844 - loss: 0.4251 - val_accuracy: 0.7406 - val_loss: 0.4767
# Epoch 21/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8086 - loss: 0.4001 - val_accuracy: 0.7281 - val_loss: 0.4846
# Epoch 22/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8070 - loss: 0.3971 - val_accuracy: 0.7406 - val_loss: 0.4717
# Epoch 23/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7828 - loss: 0.4132 - val_accuracy: 0.7375 - val_loss: 0.4829
# Epoch 24/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8141 - loss: 0.4008 - val_accuracy: 0.7719 - val_loss: 0.4683
# Epoch 25/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7961 - loss: 0.3819 - val_accuracy: 0.7563 - val_loss: 0.4730
# Epoch 26/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8086 - loss: 0.3797 - val_accuracy: 0.7344 - val_loss: 0.4804
# Epoch 27/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8086 - loss: 0.3790 - val_accuracy: 0.7500 - val_loss: 0.4717
# Epoch 28/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8234 - loss: 0.3632 - val_accuracy: 0.7563 - val_loss: 0.4774
# Epoch 29/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8414 - loss: 0.3460 - val_accuracy: 0.7344 - val_loss: 0.5053
# Epoch 30/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8203 - loss: 0.3720 - val_accuracy: 0.7594 - val_loss: 0.4599
# Epoch 31/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8453 - loss: 0.3530 - val_accuracy: 0.7750 - val_loss: 0.4836
# Epoch 32/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8375 - loss: 0.3652 - val_accuracy: 0.7656 - val_loss: 0.4456
# Epoch 33/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8211 - loss: 0.3500 - val_accuracy: 0.7437 - val_loss: 0.4597
# Epoch 34/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8398 - loss: 0.3516 - val_accuracy: 0.7594 - val_loss: 0.4674
# Epoch 35/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8359 - loss: 0.3523 - val_accuracy: 0.7656 - val_loss: 0.4635
# Epoch 36/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8391 - loss: 0.3305 - val_accuracy: 0.7563 - val_loss: 0.4660
# Epoch 37/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8445 - loss: 0.3267 - val_accuracy: 0.7594 - val_loss: 0.4690
# Epoch 38/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8383 - loss: 0.3368 - val_accuracy: 0.7563 - val_loss: 0.4699
# Epoch 39/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8461 - loss: 0.3361 - val_accuracy: 0.7688 - val_loss: 0.4589
# Epoch 40/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8398 - loss: 0.3234 - val_accuracy: 0.7719 - val_loss: 0.4533
# Epoch 41/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8578 - loss: 0.3016 - val_accuracy: 0.7625 - val_loss: 0.5010
# Epoch 42/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8438 - loss: 0.2986 - val_accuracy: 0.7937 - val_loss: 0.4736
# Epoch 43/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8570 - loss: 0.2972 - val_accuracy: 0.7625 - val_loss: 0.4747
# Epoch 44/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8641 - loss: 0.2888 - val_accuracy: 0.7906 - val_loss: 0.4725
# Epoch 45/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8664 - loss: 0.2843 - val_accuracy: 0.7750 - val_loss: 0.5057
# Epoch 46/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8539 - loss: 0.3089 - val_accuracy: 0.7594 - val_loss: 0.4904
# Epoch 47/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8500 - loss: 0.3172 - val_accuracy: 0.7750 - val_loss: 0.4875
# Epoch 48/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8641 - loss: 0.2813 - val_accuracy: 0.7906 - val_loss: 0.4903
# Epoch 49/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8625 - loss: 0.2881 - val_accuracy: 0.7906 - val_loss: 0.4671
# Epoch 50/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8695 - loss: 0.2876 - val_accuracy: 0.7625 - val_loss: 0.4993

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
